# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.30.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.29.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from selenium) (2024.12.14)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sortedcontainers in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.30.0-py3-none-any.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.4 MB 11.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.9/9.4 MB 13.8 MB/s eta 0:00:01
#    ------------------------------ --------- 7.1/9.4 MB 14.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 13.2 MB/s eta 0:00:00
# Downloading trio-0.29.0-py3-none-any.whl (492 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, attrs, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-25.3.0 outcome-1.3.0.post0 selenium-4.30.0 trio-0.29.0 trio-websocket-0.12.2 wsproto-1.2.0

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
import pandas as pd
from datetime import datetime, timedelta

def scrape_billboard_radio_songs_with_dates(start_date, end_date, weekly=True, preview_rows=3):
    """
    Scrape Billboard Streaming Songs for multiple dates
    
    Parameters:
    start_date (str): Start date in 'YYYY-MM-DD' format
    end_date (str): End date in 'YYYY-MM-DD' format
    weekly (bool): If True, capture weekly data, otherwise try every day (not recommended)
    preview_rows (int): Number of rows to show in preview (default 3)
    """
    # Convert string dates to datetime objects
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    
    # Configure Chrome to run without JavaScript
    chrome_options = Options()
    chrome_options.add_experimental_option("prefs", {"profile.managed_default_content_settings.javascript": 2})
    
    # Initialize the driver
    driver = webdriver.Chrome(options=chrome_options)
    
    # Initialize a list to store all data from all dates
    all_chart_data = []
    
    try:
        # Generate a list of dates to scrape
        current_date = start
        date_increment = timedelta(days=7) if weekly else timedelta(days=1)
        
        while current_date <= end:
            # Format the date for the URL
            formatted_date = current_date.strftime('%Y-%m-%d')
            
            # Build the URL with the date
            url = f"https://www.billboard.com/charts/streaming-songs/{formatted_date}/"
            print(f"\nScraping data for {formatted_date}...")
            
            # Access the page
            driver.get(url)
            
            # Wait for the page to load
            time.sleep(3)
            
            # Get the HTML content
            html_content = driver.page_source
            
            # Check if the page has a "Page not found" message
            if "Page Not Found" in html_content:
                print(f"No data available for {formatted_date}, skipping...")
                current_date += date_increment
                continue
            
            # Use BeautifulSoup to parse the HTML
            soup = BeautifulSoup(html_content, 'html.parser')
            
            # Find all song rows
            song_rows = soup.select('div.o-chart-results-list-row-container')
            print(f"Found {len(song_rows)} song rows for {formatted_date}")
            
            # If no songs found, skip this date
            if len(song_rows) == 0:
                print(f"No songs found for {formatted_date}, skipping...")
                current_date += date_increment
                continue
            
            # Track how many rows we've processed for preview
            rows_processed = 0
            
            # Process each song row
            for row in song_rows:
                try:
                    # Extract rank - the big number on the left
                    rank_elem = row.select_one('span.c-label.a-font-primary-bold-l')
                    rank = rank_elem.text.strip() if rank_elem else "N/A"
                    
                    # Extract title
                    title_elem = row.select_one('h3#title-of-a-story')
                    title = title_elem.text.strip() if title_elem else "N/A"
                    
                    # Extract artist
                    artist_elem = row.select_one('span.c-label.a-font-primary-s')
                    artist = artist_elem.text.strip() if artist_elem else "N/A"
                    
                    # All data spans in the row
                    all_spans = row.select('span.c-label')
                    
                    # Find numbers not associated with rank or labels
                    number_spans = []
                    for span in all_spans:
                        text = span.text.strip()
                        # Skip the rank number and artist
                        if span == rank_elem or span == artist_elem:
                            continue
                        if text.isdigit() or text == '★' or text == '-':
                            number_spans.append(text)
                    
                    # The last 3 numbers should be our statistics
                    last_week = peak_pos = weeks_on_chart = "N/A"
                    if len(number_spans) >= 3:
                        last_week = number_spans[-3]
                        peak_pos = number_spans[-2]
                        weeks_on_chart = number_spans[-1]
                    
                    # Special handling for the first song if statistics are missing
                    if rank == "1" and (last_week == "N/A" or peak_pos == "N/A" or weeks_on_chart == "N/A"):
                        # Try to find stats in the parent container
                        parent = row.find_parent('li')
                        if parent:
                            all_numbers = []
                            for elem in parent.select('span.c-label'):
                                text = elem.text.strip()
                                if text.isdigit() or text == '★' or text == '-':
                                    all_numbers.append(text)
                            
                            # Filter out the rank number
                            all_numbers = [n for n in all_numbers if n != rank]
                            
                            if len(all_numbers) >= 3:
                                last_week = all_numbers[-3]
                                peak_pos = all_numbers[-2]
                                weeks_on_chart = all_numbers[-1]
                    
                    # Add the data with the chart date
                    all_chart_data.append({
                        'Chart Date': formatted_date,
                        'Rank': rank,
                        'Title': title,
                        'Artist': artist,
                        'Last Week': last_week,
                        'Peak Position': peak_pos,
                        'Weeks on Chart': weeks_on_chart
                    })
                    
                    # Only print for the first preview_rows rows
                    rows_processed += 1
                    if rows_processed <= preview_rows:
                        print(f"Added: {formatted_date} - {rank}. {title} - {artist} | LW: {last_week} | Peak: {peak_pos} | Weeks: {weeks_on_chart}")
                    elif rows_processed == preview_rows + 1:
                        print(f"... (collecting remaining {len(song_rows) - preview_rows} songs) ...")
                    
                except Exception as e:
                    print(f"Error processing row: {e}")
            
            # Move to the next date
            current_date += date_increment
            
            # Add a small delay between requests to be considerate
            time.sleep(2)
        
        # Create a DataFrame for all the extracted data
        df = pd.DataFrame(all_chart_data)
        
        # Save the data to a CSV file
        output_filename = f'billboard_streaming_songs_{start_date}_to_{end_date}.csv'
        df.to_csv(output_filename, index=False)
        print(f"\nAll data saved to '{output_filename}'")
        
        return df
        
    finally:
        # Close the browser
        driver.quit()

if __name__ == "__main__":
    # Example usage: Scrape Billboard Streaming Songs charts for a 1-year period
    start_date = "2024-01-06"  # Format: YYYY-MM-DD
    end_date = "2024-12-28"    # Format: YYYY-MM-DD
    
    # You can change these dates to any period you're interested in
    scrape_billboard_radio_songs_with_dates(start_date, end_date, preview_rows=3)
# Out:
# Scraping data for 2024-01-06...
# Found 50 song rows for 2024-01-06
# Added: 2024-01-06 - 1. Rockin' Around The Christmas Tree - Brenda Lee | LW: 1 | Peak: 1 | Weeks: 50
# Added: 2024-01-06 - 2. All I Want For Christmas Is You - Mariah Carey | LW: 2 | Peak: 1 | Weeks: 62
# Added: 2024-01-06 - 3. Jingle Bell Rock - Bobby Helms | LW: 3 | Peak: 2 | Weeks: 43
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-01-13...
# Found 50 song rows for 2024-01-13
# Added: 2024-01-13 - 1. Lovin On Me - Jack Harlow | LW: 19 | Peak: 1 | Weeks: 8
# Added: 2024-01-13 - 2. I Remember Everything - Zach Bryan Featuring Kacey Musgraves | LW: 28 | Peak: 1 | Weeks: 19
# Added: 2024-01-13 - 3. Cruel Summer - Taylor Swift | LW: 49 | Peak: 1 | Weeks: 37
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-01-20...
# Found 50 song rows for 2024-01-20
# Added: 2024-01-20 - 1. Lovin On Me - Jack Harlow | LW: 1 | Peak: 1 | Weeks: 9
# Added: 2024-01-20 - 2. I Remember Everything - Zach Bryan Featuring Kacey Musgraves | LW: 2 | Peak: 1 | Weeks: 20
# Added: 2024-01-20 - 3. Stick Season - Noah Kahan | LW: 7 | Peak: 3 | Weeks: 12
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-01-27...
# Found 50 song rows for 2024-01-27
# Added: 2024-01-27 - 1. Yes, And? - Ariana Grande | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-01-27 - 2. Lovin On Me - Jack Harlow | LW: 1 | Peak: 1 | Weeks: 10
# Added: 2024-01-27 - 3. Redrum - 21 Savage | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-02-03...
# Found 50 song rows for 2024-02-03
# Added: 2024-02-03 - 1. Lovin On Me - Jack Harlow | LW: 2 | Peak: 1 | Weeks: 11
# Added: 2024-02-03 - 2. I Remember Everything - Zach Bryan Featuring Kacey Musgraves | LW: 5 | Peak: 1 | Weeks: 22
# Added: 2024-02-03 - 3. Redrum - 21 Savage | LW: 3 | Peak: 3 | Weeks: 2
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-02-10...
# Found 50 song rows for 2024-02-10
# Added: 2024-02-10 - 1. Hiss - Megan Thee Stallion | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-02-10 - 2. Lovin On Me - Jack Harlow | LW: 1 | Peak: 1 | Weeks: 12
# Added: 2024-02-10 - 3. I Remember Everything - Zach Bryan Featuring Kacey Musgraves | LW: 2 | Peak: 1 | Weeks: 23
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-02-17...
# Found 50 song rows for 2024-02-17
# Added: 2024-02-17 - 1. Beautiful Things - Benson Boone | LW: 5 | Peak: 1 | Weeks: 3
# Added: 2024-02-17 - 2. I Remember Everything - Zach Bryan Featuring Kacey Musgraves | LW: 3 | Peak: 1 | Weeks: 24
# Added: 2024-02-17 - 3. Lovin On Me - Jack Harlow | LW: 2 | Peak: 1 | Weeks: 13
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-02-24...
# Found 50 song rows for 2024-02-24
# Added: 2024-02-24 - 1. Carnival - ¥$: Ye & Ty Dolla $ign Featuring Rich The Kid & Playboi Carti | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-02-24 - 2. Beautiful Things - Benson Boone | LW: 1 | Peak: 1 | Weeks: 4
# Added: 2024-02-24 - 3. I Remember Everything - Zach Bryan Featuring Kacey Musgraves | LW: 2 | Peak: 1 | Weeks: 25
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-03-02...
# Found 50 song rows for 2024-03-02
# Added: 2024-03-02 - 1. Texas Hold 'Em - Beyonce | LW: 4 | Peak: 1 | Weeks: 2
# Added: 2024-03-02 - 2. Carnival - ¥$: Ye & Ty Dolla $ign Featuring Rich The Kid & Playboi Carti | LW: 1 | Peak: 1 | Weeks: 2
# Added: 2024-03-02 - 3. Beautiful Things - Benson Boone | LW: 2 | Peak: 1 | Weeks: 5
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-03-09...
# Found 50 song rows for 2024-03-09
# Added: 2024-03-09 - 1. Carnival - ¥$: Ye & Ty Dolla $ign Featuring Rich The Kid & Playboi Carti | LW: 2 | Peak: 1 | Weeks: 3
# Added: 2024-03-09 - 2. Saturn - SZA | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-03-09 - 3. Texas Hold 'Em - Beyonce | LW: 1 | Peak: 1 | Weeks: 3
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-03-16...
# Found 50 song rows for 2024-03-16
# Added: 2024-03-16 - 1. Carnival - ¥$: Ye & Ty Dolla $ign Featuring Rich The Kid & Playboi Carti | LW: 1 | Peak: 1 | Weeks: 4
# Added: 2024-03-16 - 2. Beautiful Things - Benson Boone | LW: 4 | Peak: 1 | Weeks: 7
# Added: 2024-03-16 - 3. Lose Control - Teddy Swims | LW: 6 | Peak: 3 | Weeks: 15
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-03-23...
# Found 50 song rows for 2024-03-23
# Added: 2024-03-23 - 1. We Can't Be Friends (Wait For Your Love) - Ariana Grande | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-03-23 - 2. Carnival - ¥$: Ye & Ty Dolla $ign Featuring Rich The Kid & Playboi Carti | LW: 1 | Peak: 1 | Weeks: 5
# Added: 2024-03-23 - 3. Beautiful Things - Benson Boone | LW: 2 | Peak: 1 | Weeks: 8
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-03-30...
# Found 50 song rows for 2024-03-30
# Added: 2024-03-30 - 1. We Can't Be Friends (Wait For Your Love) - Ariana Grande | LW: 1 | Peak: 1 | Weeks: 2
# Added: 2024-03-30 - 2. Carnival - ¥$: Ye & Ty Dolla $ign Featuring Rich The Kid & Playboi Carti | LW: 2 | Peak: 1 | Weeks: 6
# Added: 2024-03-30 - 3. Beautiful Things - Benson Boone | LW: 3 | Peak: 1 | Weeks: 9
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-04-06...
# Found 50 song rows for 2024-04-06
# Added: 2024-04-06 - 1. Like That - Future, Metro Boomin & Kendrick Lamar | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-04-06 - 2. Type Shit - Future, Metro Boomin, Travis Scott & Playboi Carti | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-04-06 - 3. Too Sweet - Hozier | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-04-13...
# Found 50 song rows for 2024-04-13
# Added: 2024-04-13 - 1. Like That - Future, Metro Boomin & Kendrick Lamar | LW: 1 | Peak: 1 | Weeks: 2
# Added: 2024-04-13 - 2. Too Sweet - Hozier | LW: 3 | Peak: 2 | Weeks: 2
# Added: 2024-04-13 - 3. Texas Hold 'Em - Beyonce | LW: 21 | Peak: 1 | Weeks: 8
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-04-20...
# Found 50 song rows for 2024-04-20
# Added: 2024-04-20 - 1. Like That - Future, Metro Boomin & Kendrick Lamar | LW: 1 | Peak: 1 | Weeks: 3
# Added: 2024-04-20 - 2. Too Sweet - Hozier | LW: 2 | Peak: 2 | Weeks: 3
# Added: 2024-04-20 - 3. Beautiful Things - Benson Boone | LW: 5 | Peak: 1 | Weeks: 12
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-04-27...
# Found 50 song rows for 2024-04-27
# Added: 2024-04-27 - 1. Too Sweet - Hozier | LW: 2 | Peak: 1 | Weeks: 4
# Added: 2024-04-27 - 2. Like That - Future, Metro Boomin & Kendrick Lamar | LW: 1 | Peak: 1 | Weeks: 4
# Added: 2024-04-27 - 3. Beautiful Things - Benson Boone | LW: 3 | Peak: 1 | Weeks: 13
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-05-04...
# Found 50 song rows for 2024-05-04
# Added: 2024-05-04 - 1. Fortnight - Taylor Swift Featuring Post Malone | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-05-04 - 2. Down Bad - Taylor Swift | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-05-04 - 3. The Tortured Poets Department - Taylor Swift | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-05-11...
# Found 50 song rows for 2024-05-11
# Added: 2024-05-11 - 1. Million Dollar Baby - Tommy Richman | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-05-11 - 2. Fortnight - Taylor Swift Featuring Post Malone | LW: 1 | Peak: 1 | Weeks: 2
# Added: 2024-05-11 - 3. A Bar Song (Tipsy) - Shaboozey | LW: 25 | Peak: 3 | Weeks: 3
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-05-18...
# Found 50 song rows for 2024-05-18
# Added: 2024-05-18 - 1. Not Like Us - Kendrick Lamar | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-05-18 - 2. Million Dollar Baby - Tommy Richman | LW: 1 | Peak: 1 | Weeks: 2
# Added: 2024-05-18 - 3. Euphoria - Kendrick Lamar | LW: 9 | Peak: 3 | Weeks: 2
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-05-25...
# Found 50 song rows for 2024-05-25
# Added: 2024-05-25 - 1. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-05-25 - 2. Not Like Us - Kendrick Lamar | LW: 1 | Peak: 1 | Weeks: 2
# Added: 2024-05-25 - 3. Million Dollar Baby - Tommy Richman | LW: 2 | Peak: 1 | Weeks: 3
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-06-01...
# Found 50 song rows for 2024-06-01
# Added: 2024-06-01 - 1. Not Like Us - Kendrick Lamar | LW: 2 | Peak: 1 | Weeks: 3
# Added: 2024-06-01 - 2. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 1 | Peak: 1 | Weeks: 2
# Added: 2024-06-01 - 3. Million Dollar Baby - Tommy Richman | LW: 3 | Peak: 1 | Weeks: 4
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-06-08...
# Found 50 song rows for 2024-06-08
# Added: 2024-06-08 - 1. Not Like Us - Kendrick Lamar | LW: 1 | Peak: 1 | Weeks: 4
# Added: 2024-06-08 - 2. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 2 | Peak: 1 | Weeks: 3
# Added: 2024-06-08 - 3. Million Dollar Baby - Tommy Richman | LW: 3 | Peak: 1 | Weeks: 5
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-06-15...
# Found 50 song rows for 2024-06-15
# Added: 2024-06-15 - 1. Houdini - Eminem | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-06-15 - 2. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 2 | Peak: 1 | Weeks: 4
# Added: 2024-06-15 - 3. Million Dollar Baby - Tommy Richman | LW: 3 | Peak: 1 | Weeks: 6
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-06-22...
# Found 50 song rows for 2024-06-22
# Added: 2024-06-22 - 1. Please Please Please - Sabrina Carpenter | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-06-22 - 2. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 2 | Peak: 1 | Weeks: 5
# Added: 2024-06-22 - 3. Espresso - Sabrina Carpenter | LW: 6 | Peak: 3 | Weeks: 9
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-06-29...
# Found 50 song rows for 2024-06-29
# Added: 2024-06-29 - 1. Please Please Please - Sabrina Carpenter | LW: 1 | Peak: 1 | Weeks: 2
# Added: 2024-06-29 - 2. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 2 | Peak: 1 | Weeks: 6
# Added: 2024-06-29 - 3. A Bar Song (Tipsy) - Shaboozey | LW: 4 | Peak: 3 | Weeks: 10
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-07-06...
# Found 50 song rows for 2024-07-06
# Added: 2024-07-06 - 1. Not Like Us - Kendrick Lamar | LW: 6 | Peak: 1 | Weeks: 8
# Added: 2024-07-06 - 2. Please Please Please - Sabrina Carpenter | LW: 1 | Peak: 1 | Weeks: 3
# Added: 2024-07-06 - 3. A Bar Song (Tipsy) - Shaboozey | LW: 3 | Peak: 3 | Weeks: 11
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-07-13...
# Found 50 song rows for 2024-07-13
# Added: 2024-07-13 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 3 | Peak: 1 | Weeks: 12
# Added: 2024-07-13 - 2. Not Like Us - Kendrick Lamar | LW: 1 | Peak: 1 | Weeks: 9
# Added: 2024-07-13 - 3. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 4 | Peak: 1 | Weeks: 8
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-07-20...
# Found 50 song rows for 2024-07-20
# Added: 2024-07-20 - 1. Not Like Us - Kendrick Lamar | LW: 2 | Peak: 1 | Weeks: 10
# Added: 2024-07-20 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 13
# Added: 2024-07-20 - 3. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 3 | Peak: 1 | Weeks: 9
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-07-27...
# Found 50 song rows for 2024-07-27
# Added: 2024-07-27 - 1. Not Like Us - Kendrick Lamar | LW: 1 | Peak: 1 | Weeks: 11
# Added: 2024-07-27 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 14
# Added: 2024-07-27 - 3. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 3 | Peak: 1 | Weeks: 10
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-08-03...
# Found 50 song rows for 2024-08-03
# Added: 2024-08-03 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 15
# Added: 2024-08-03 - 2. Not Like Us - Kendrick Lamar | LW: 1 | Peak: 1 | Weeks: 12
# Added: 2024-08-03 - 3. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 3 | Peak: 1 | Weeks: 11
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-08-10...
# Found 50 song rows for 2024-08-10
# Added: 2024-08-10 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 16
# Added: 2024-08-10 - 2. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 3 | Peak: 1 | Weeks: 12
# Added: 2024-08-10 - 3. Not Like Us - Kendrick Lamar | LW: 2 | Peak: 1 | Weeks: 13
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-08-17...
# Found 50 song rows for 2024-08-17
# Added: 2024-08-17 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 17
# Added: 2024-08-17 - 2. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 2 | Peak: 1 | Weeks: 13
# Added: 2024-08-17 - 3. Not Like Us - Kendrick Lamar | LW: 3 | Peak: 1 | Weeks: 14
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-08-24...
# Found 50 song rows for 2024-08-24
# Added: 2024-08-24 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 18
# Added: 2024-08-24 - 2. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 2 | Peak: 1 | Weeks: 14
# Added: 2024-08-24 - 3. Not Like Us - Kendrick Lamar | LW: 3 | Peak: 1 | Weeks: 15
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-08-31...
# Found 50 song rows for 2024-08-31
# Added: 2024-08-31 - 1. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 2 | Peak: 1 | Weeks: 15
# Added: 2024-08-31 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 19
# Added: 2024-08-31 - 3. Die With A Smile - Lady Gaga & Bruno Mars | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-09-07...
# Found 50 song rows for 2024-09-07
# Added: 2024-09-07 - 1. Taste - Sabrina Carpenter | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-09-07 - 2. Please Please Please - Sabrina Carpenter | LW: 7 | Peak: 1 | Weeks: 12
# Added: 2024-09-07 - 3. Die With A Smile - Lady Gaga & Bruno Mars | LW: 3 | Peak: 3 | Weeks: 2
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-09-14...
# Found 50 song rows for 2024-09-14
# Added: 2024-09-14 - 1. Taste - Sabrina Carpenter | LW: 1 | Peak: 1 | Weeks: 2
# Added: 2024-09-14 - 2. Die With A Smile - Lady Gaga & Bruno Mars | LW: 3 | Peak: 2 | Weeks: 3
# Added: 2024-09-14 - 3. A Bar Song (Tipsy) - Shaboozey | LW: 5 | Peak: 1 | Weeks: 21
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-09-21...
# Found 50 song rows for 2024-09-21
# Added: 2024-09-21 - 1. Taste - Sabrina Carpenter | LW: 1 | Peak: 1 | Weeks: 3
# Added: 2024-09-21 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 3 | Peak: 1 | Weeks: 22
# Added: 2024-09-21 - 3. Die With A Smile - Lady Gaga & Bruno Mars | LW: 2 | Peak: 2 | Weeks: 4
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-09-28...
# Found 50 song rows for 2024-09-28
# Added: 2024-09-28 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 23
# Added: 2024-09-28 - 2. Taste - Sabrina Carpenter | LW: 1 | Peak: 1 | Weeks: 4
# Added: 2024-09-28 - 3. Die With A Smile - Lady Gaga & Bruno Mars | LW: 3 | Peak: 2 | Weeks: 5
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-10-05...
# Found 50 song rows for 2024-10-05
# Added: 2024-10-05 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 24
# Added: 2024-10-05 - 2. Die With A Smile - Lady Gaga & Bruno Mars | LW: 3 | Peak: 2 | Weeks: 6
# Added: 2024-10-05 - 3. Taste - Sabrina Carpenter | LW: 2 | Peak: 1 | Weeks: 5
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-10-12...
# Found 50 song rows for 2024-10-12
# Added: 2024-10-12 - 1. Timeless - The Weeknd & Playboi Carti | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-10-12 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 25
# Added: 2024-10-12 - 3. Die With A Smile - Lady Gaga & Bruno Mars | LW: 2 | Peak: 2 | Weeks: 7
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-10-19...
# Found 50 song rows for 2024-10-19
# Added: 2024-10-19 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 26
# Added: 2024-10-19 - 2. Die With A Smile - Lady Gaga & Bruno Mars | LW: 3 | Peak: 2 | Weeks: 8
# Added: 2024-10-19 - 3. Taste - Sabrina Carpenter | LW: 4 | Peak: 1 | Weeks: 7
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-10-26...
# Found 50 song rows for 2024-10-26
# Added: 2024-10-26 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 27
# Added: 2024-10-26 - 2. Birds Of A Feather - Billie Eilish | LW: 4 | Peak: 2 | Weeks: 22
# Added: 2024-10-26 - 3. Die With A Smile - Lady Gaga & Bruno Mars | LW: 2 | Peak: 2 | Weeks: 9
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-11-02...
# Found 50 song rows for 2024-11-02
# Added: 2024-11-02 - 1. Love Somebody - Morgan Wallen | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-11-02 - 2. APT. - ROSE & Bruno Mars | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-11-02 - 3. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 28
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-11-09...
# Found 50 song rows for 2024-11-09
# Added: 2024-11-09 - 1. St. Chroma - Tyler, The Creator Featuring Daniel Caesar | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-11-09 - 2. Noid - Tyler, The Creator | LW: 31 | Peak: 2 | Weeks: 2
# Added: 2024-11-09 - 3. Love Somebody - Morgan Wallen | LW: 1 | Peak: 1 | Weeks: 2
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-11-16...
# Found 50 song rows for 2024-11-16
# Added: 2024-11-16 - 1. Sticky - Tyler, The Creator Featuring GloRilla, Sexyy Red & Lil Wayne | LW: 4 | Peak: 1 | Weeks: 2
# Added: 2024-11-16 - 2. Die With A Smile - Lady Gaga & Bruno Mars | LW: 5 | Peak: 2 | Weeks: 12
# Added: 2024-11-16 - 3. St. Chroma - Tyler, The Creator Featuring Daniel Caesar | LW: 1 | Peak: 1 | Weeks: 2
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-11-23...
# Found 50 song rows for 2024-11-23
# Added: 2024-11-23 - 1. That's So True - Gracie Abrams | LW: 4 | Peak: 1 | Weeks: 4
# Added: 2024-11-23 - 2. Die With A Smile - Lady Gaga & Bruno Mars | LW: 2 | Peak: 2 | Weeks: 13
# Added: 2024-11-23 - 3. Birds Of A Feather - Billie Eilish | LW: 7 | Peak: 2 | Weeks: 26
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-11-30...
# Found 50 song rows for 2024-11-30
# Added: 2024-11-30 - 1. That's So True - Gracie Abrams | LW: 1 | Peak: 1 | Weeks: 5
# Added: 2024-11-30 - 2. Die With A Smile - Lady Gaga & Bruno Mars | LW: 2 | Peak: 2 | Weeks: 14
# Added: 2024-11-30 - 3. Sticky - Tyler, The Creator Featuring GloRilla, Sexyy Red & Lil Wayne | LW: 6 | Peak: 1 | Weeks: 4
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-12-07...
# Found 50 song rows for 2024-12-07
# Added: 2024-12-07 - 1. Squabble Up - Kendrick Lamar | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-12-07 - 2. TV Off - Kendrick Lamar Featuring Lefty Gunplay | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-12-07 - 3. Luther - Kendrick Lamar & SZA | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-12-14...
# Found 50 song rows for 2024-12-14
# Added: 2024-12-14 - 1. All I Want For Christmas Is You - Mariah Carey | LW: 10 | Peak: 1 | Weeks: 67
# Added: 2024-12-14 - 2. TV Off - Kendrick Lamar Featuring Lefty Gunplay | LW: 2 | Peak: 2 | Weeks: 2
# Added: 2024-12-14 - 3. Rockin' Around The Christmas Tree - Brenda Lee | LW: 13 | Peak: 1 | Weeks: 54
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-12-21...
# Found 50 song rows for 2024-12-21
# Added: 2024-12-21 - 1. All I Want For Christmas Is You - Mariah Carey | LW: 1 | Peak: 1 | Weeks: 68
# Added: 2024-12-21 - 2. Rockin' Around The Christmas Tree - Brenda Lee | LW: 3 | Peak: 1 | Weeks: 55
# Added: 2024-12-21 - 3. Jingle Bell Rock - Bobby Helms | LW: 6 | Peak: 2 | Weeks: 48
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2024-12-28...
# Found 50 song rows for 2024-12-28
# Added: 2024-12-28 - 1. All I Want For Christmas Is You - Mariah Carey | LW: 1 | Peak: 1 | Weeks: 69
# Added: 2024-12-28 - 2. Rockin' Around The Christmas Tree - Brenda Lee | LW: 2 | Peak: 1 | Weeks: 56
# Added: 2024-12-28 - 3. Last Christmas - Wham! | LW: 4 | Peak: 3 | Weeks: 47
# ... (collecting remaining 47 songs) ...
#
# Scraping data for 2025-01-04...
# Found 50 song rows for 2025-01-04
# Added: 2025-01-04 - 1. All I Want For Christmas Is You - Mariah Carey | LW: 1 | Peak: 1 | Weeks: 70
# Added: 2025-01-04 - 2. Rockin' Around The Christmas Tree - Brenda Lee | LW: 2 | Peak: 1 | Weeks: 57
# Added: 2025-01-04 - 3. Last Christmas - Wham! | LW: 3 | Peak: 3 | Weeks: 48
# ... (collecting remaining 47 songs) ...
#
# All data saved to 'billboard_streaming_songs_2024-01-06_to_2025-01-04.csv'
