# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.30.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.29.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from selenium) (2024.12.14)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sortedcontainers in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.30.0-py3-none-any.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.4 MB 11.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.9/9.4 MB 13.8 MB/s eta 0:00:01
#    ------------------------------ --------- 7.1/9.4 MB 14.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 13.2 MB/s eta 0:00:00
# Downloading trio-0.29.0-py3-none-any.whl (492 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, attrs, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-25.3.0 outcome-1.3.0.post0 selenium-4.30.0 trio-0.29.0 trio-websocket-0.12.2 wsproto-1.2.0

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\w196283\appdata\local\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
import pandas as pd
from datetime import datetime, timedelta

def scrape_billboard_radio_songs_with_dates(start_date, end_date, weekly=True, preview_rows=3):
    """
    Scrape Billboard Digital Song Sales for multiple dates
    
    Parameters:
    start_date (str): Start date in 'YYYY-MM-DD' format
    end_date (str): End date in 'YYYY-MM-DD' format
    weekly (bool): If True, capture weekly data, otherwise try every day (not recommended)
    preview_rows (int): Number of rows to show in preview (default 3)
    """
    # Convert string dates to datetime objects
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    
    # Configure Chrome to run without JavaScript
    chrome_options = Options()
    chrome_options.add_experimental_option("prefs", {"profile.managed_default_content_settings.javascript": 2})
    
    # Initialize the driver
    driver = webdriver.Chrome(options=chrome_options)
    
    # Initialize a list to store all data from all dates
    all_chart_data = []
    
    try:
        # Generate a list of dates to scrape
        current_date = start
        date_increment = timedelta(days=7) if weekly else timedelta(days=1)
        
        while current_date <= end:
            # Format the date for the URL
            formatted_date = current_date.strftime('%Y-%m-%d')
            
            # Build the URL with the date
            url = f"https://www.billboard.com/charts/digital-song-sales/{formatted_date}/"
            print(f"\nScraping data for {formatted_date}...")
            
            # Access the page
            driver.get(url)
            
            # Wait for the page to load
            time.sleep(3)
            
            # Get the HTML content
            html_content = driver.page_source
            
            # Check if the page has a "Page not found" message
            if "Page Not Found" in html_content:
                print(f"No data available for {formatted_date}, skipping...")
                current_date += date_increment
                continue
            
            # Use BeautifulSoup to parse the HTML
            soup = BeautifulSoup(html_content, 'html.parser')
            
            # Find all song rows
            song_rows = soup.select('div.o-chart-results-list-row-container')
            print(f"Found {len(song_rows)} song rows for {formatted_date}")
            
            # If no songs found, skip this date
            if len(song_rows) == 0:
                print(f"No songs found for {formatted_date}, skipping...")
                current_date += date_increment
                continue
            
            # Track how many rows we've processed for preview
            rows_processed = 0
            
            # Process each song row
            for row in song_rows:
                try:
                    # Extract rank - the big number on the left
                    rank_elem = row.select_one('span.c-label.a-font-primary-bold-l')
                    rank = rank_elem.text.strip() if rank_elem else "N/A"
                    
                    # Extract title
                    title_elem = row.select_one('h3#title-of-a-story')
                    title = title_elem.text.strip() if title_elem else "N/A"
                    
                    # Extract artist
                    artist_elem = row.select_one('span.c-label.a-font-primary-s')
                    artist = artist_elem.text.strip() if artist_elem else "N/A"
                    
                    # All data spans in the row
                    all_spans = row.select('span.c-label')
                    
                    # Find numbers not associated with rank or labels
                    number_spans = []
                    for span in all_spans:
                        text = span.text.strip()
                        # Skip the rank number and artist
                        if span == rank_elem or span == artist_elem:
                            continue
                        if text.isdigit() or text == '★' or text == '-':
                            number_spans.append(text)
                    
                    # The last 3 numbers should be our statistics
                    last_week = peak_pos = weeks_on_chart = "N/A"
                    if len(number_spans) >= 3:
                        last_week = number_spans[-3]
                        peak_pos = number_spans[-2]
                        weeks_on_chart = number_spans[-1]
                    
                    # Special handling for the first song if statistics are missing
                    if rank == "1" and (last_week == "N/A" or peak_pos == "N/A" or weeks_on_chart == "N/A"):
                        # Try to find stats in the parent container
                        parent = row.find_parent('li')
                        if parent:
                            all_numbers = []
                            for elem in parent.select('span.c-label'):
                                text = elem.text.strip()
                                if text.isdigit() or text == '★' or text == '-':
                                    all_numbers.append(text)
                            
                            # Filter out the rank number
                            all_numbers = [n for n in all_numbers if n != rank]
                            
                            if len(all_numbers) >= 3:
                                last_week = all_numbers[-3]
                                peak_pos = all_numbers[-2]
                                weeks_on_chart = all_numbers[-1]
                    
                    # Add the data with the chart date
                    all_chart_data.append({
                        'Chart Date': formatted_date,
                        'Rank': rank,
                        'Title': title,
                        'Artist': artist,
                        'Last Week': last_week,
                        'Peak Position': peak_pos,
                        'Weeks on Chart': weeks_on_chart
                    })
                    
                    # Only print for the first preview_rows rows
                    rows_processed += 1
                    if rows_processed <= preview_rows:
                        print(f"Added: {formatted_date} - {rank}. {title} - {artist} | LW: {last_week} | Peak: {peak_pos} | Weeks: {weeks_on_chart}")
                    elif rows_processed == preview_rows + 1:
                        print(f"... (collecting remaining {len(song_rows) - preview_rows} songs) ...")
                    
                except Exception as e:
                    print(f"Error processing row: {e}")
            
            # Move to the next date
            current_date += date_increment
            
            # Add a small delay between requests to be considerate
            time.sleep(2)
        
        # Create a DataFrame for all the extracted data
        df = pd.DataFrame(all_chart_data)
        
        # Save the data to a CSV file
        output_filename = f'billboard_digital_song_sales_{start_date}_to_{end_date}.csv'
        df.to_csv(output_filename, index=False)
        print(f"\nAll data saved to '{output_filename}'")
        
        return df
        
    finally:
        # Close the browser
        driver.quit()

if __name__ == "__main__":
    # Example usage: Scrape Billboard Digital Song Sales charts for a 1-year period
    start_date = "2024-01-06"  # Format: YYYY-MM-DD
    end_date = "2024-12-28"    # Format: YYYY-MM-DD
    
    # You can change these dates to any period you're interested in
    scrape_billboard_radio_songs_with_dates(start_date, end_date, preview_rows=3)
# Out:
# Scraping data for 2024-01-06...
# Found 25 song rows for 2024-01-06
# Added: 2024-01-06 - 1. Closer Than This - Jimin | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-01-06 - 2. Lovin On Me - Jack Harlow | LW: 3 | Peak: 1 | Weeks: 7
# Added: 2024-01-06 - 3. All I Want For Christmas Is You - Mariah Carey | LW: 4 | Peak: 1 | Weeks: 108
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-01-13...
# Found 25 song rows for 2024-01-13
# Added: 2024-01-13 - 1. Lovin On Me - Jack Harlow | LW: 2 | Peak: 1 | Weeks: 8
# Added: 2024-01-13 - 2. Lose Control - Teddy Swims | LW: 4 | Peak: 2 | Weeks: 25
# Added: 2024-01-13 - 3. Standing Next To You - Jung Kook | LW: 5 | Peak: 1 | Weeks: 9
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-01-20...
# Found 25 song rows for 2024-01-20
# Added: 2024-01-20 - 1. FTCU - Nicki Minaj | LW: 19 | Peak: 1 | Weeks: 3
# Added: 2024-01-20 - 2. Lovin On Me - Jack Harlow | LW: 1 | Peak: 1 | Weeks: 9
# Added: 2024-01-20 - 3. Lose Control - Teddy Swims | LW: 2 | Peak: 2 | Weeks: 26
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-01-27...
# Found 25 song rows for 2024-01-27
# Added: 2024-01-27 - 1. Yes, And? - Ariana Grande | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-01-27 - 2. Lovin On Me - Jack Harlow | LW: 2 | Peak: 1 | Weeks: 10
# Added: 2024-01-27 - 3. Lose Control - Teddy Swims | LW: 3 | Peak: 2 | Weeks: 27
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-02-03...
# Found 25 song rows for 2024-02-03
# Added: 2024-02-03 - 1. Lose Control - Teddy Swims | LW: 3 | Peak: 1 | Weeks: 28
# Added: 2024-02-03 - 2. Beautiful Things - Benson Boone | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-02-03 - 3. Lovin On Me - Jack Harlow | LW: 2 | Peak: 1 | Weeks: 11
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-02-10...
# Found 25 song rows for 2024-02-10
# Added: 2024-02-10 - 1. Hiss - Megan Thee Stallion | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-02-10 - 2. Facts - Tom MacDonald X Ben Shapiro | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-02-10 - 3. Big Foot - Nicki Minaj | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-02-17...
# Found 25 song rows for 2024-02-17
# Added: 2024-02-17 - 1. Fast Car - Tracy Chapman | LW: - | Peak: 1 | Weeks: 9
# Added: 2024-02-17 - 2. Don't Let The Old Man In - Toby Keith | LW: - | Peak: 2 | Weeks: 4
# Added: 2024-02-17 - 3. Flowers - Miley Cyrus | LW: - | Peak: 1 | Weeks: 42
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-02-24...
# Found 25 song rows for 2024-02-24
# Added: 2024-02-24 - 1. Texas Hold 'Em - Beyonce | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-02-24 - 2. 16 Carriages - Beyonce | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-02-24 - 3. Don't Let The Old Man In - Toby Keith | LW: 2 | Peak: 2 | Weeks: 5
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-03-02...
# Found 25 song rows for 2024-03-02
# Added: 2024-03-02 - 1. Texas Hold 'Em - Beyonce | LW: 1 | Peak: 1 | Weeks: 2
# Added: 2024-03-02 - 2. Lose Control - Teddy Swims | LW: 13 | Peak: 1 | Weeks: 32
# Added: 2024-03-02 - 3. Beautiful Things - Benson Boone | LW: 8 | Peak: 2 | Weeks: 5
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-03-09...
# Found 25 song rows for 2024-03-09
# Added: 2024-03-09 - 1. Beautiful Things - Benson Boone | LW: 3 | Peak: 1 | Weeks: 6
# Added: 2024-03-09 - 2. Texas Hold 'Em - Beyonce | LW: 1 | Peak: 1 | Weeks: 3
# Added: 2024-03-09 - 3. Lose Control - Teddy Swims | LW: 2 | Peak: 1 | Weeks: 33
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-03-16...
# Found 25 song rows for 2024-03-16
# Added: 2024-03-16 - 1. Lose Control - Teddy Swims | LW: 3 | Peak: 1 | Weeks: 34
# Added: 2024-03-16 - 2. Texas Hold 'Em - Beyonce | LW: 2 | Peak: 1 | Weeks: 4
# Added: 2024-03-16 - 3. Like What (Freestyle) - Cardi B | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-03-23...
# Found 25 song rows for 2024-03-23
# Added: 2024-03-23 - 1. Lose Control - Teddy Swims | LW: 1 | Peak: 1 | Weeks: 35
# Added: 2024-03-23 - 2. Beautiful Things - Benson Boone | LW: 4 | Peak: 1 | Weeks: 8
# Added: 2024-03-23 - 3. Texas Hold 'Em - Beyonce | LW: 2 | Peak: 1 | Weeks: 5
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-03-30...
# Found 25 song rows for 2024-03-30
# Added: 2024-03-30 - 1. Enough (Miami) - Cardi B | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-03-30 - 2. FRI(END)S - V | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-03-30 - 3. Beautiful Things - Benson Boone | LW: 2 | Peak: 1 | Weeks: 9
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-04-06...
# Found 25 song rows for 2024-04-06
# Added: 2024-04-06 - 1. Beautiful Things - Benson Boone | LW: 3 | Peak: 1 | Weeks: 10
# Added: 2024-04-06 - 2. Like That - Future, Metro Boomin & Kendrick Lamar | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-04-06 - 3. Texas Hold 'Em - Beyonce | LW: 5 | Peak: 1 | Weeks: 7
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-04-13...
# Found 25 song rows for 2024-04-13
# Added: 2024-04-13 - 1. Texas Hold 'Em - Beyonce | LW: 3 | Peak: 1 | Weeks: 8
# Added: 2024-04-13 - 2. Jolene - Beyonce | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-04-13 - 3. II Most Wanted - Beyonce & Miley Cyrus | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-04-20...
# Found 25 song rows for 2024-04-20
# Added: 2024-04-20 - 1. Wanna Be - GloRilla & Megan Thee Stallion | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-04-20 - 2. Beautiful Things - Benson Boone | LW: 4 | Peak: 1 | Weeks: 12
# Added: 2024-04-20 - 3. Too Sweet - Hozier | LW: 10 | Peak: 3 | Weeks: 3
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-04-27...
# Found 25 song rows for 2024-04-27
# Added: 2024-04-27 - 1. A Bar Song (Tipsy) - Shaboozey | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-04-27 - 2. Beautiful Things - Benson Boone | LW: 2 | Peak: 1 | Weeks: 13
# Added: 2024-04-27 - 3. God Mode - Tom MacDonald | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-05-04...
# Found 25 song rows for 2024-05-04
# Added: 2024-05-04 - 1. Fortnight - Taylor Swift Featuring Post Malone | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-05-04 - 2. FTCU - Nicki Minaj | LW: - | Peak: 1 | Weeks: 5
# Added: 2024-05-04 - 3. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 2
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-05-11...
# Found 25 song rows for 2024-05-11
# Added: 2024-05-11 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 3 | Peak: 1 | Weeks: 3
# Added: 2024-05-11 - 2. Beautiful Things - Benson Boone | LW: 5 | Peak: 1 | Weeks: 15
# Added: 2024-05-11 - 3. Euphoria - Kendrick Lamar | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-05-18...
# Found 25 song rows for 2024-05-18
# Added: 2024-05-18 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 4
# Added: 2024-05-18 - 2. Not Like Us - Kendrick Lamar | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-05-18 - 3. Lose Control - Teddy Swims | LW: 5 | Peak: 1 | Weeks: 43
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-05-25...
# Found 25 song rows for 2024-05-25
# Added: 2024-05-25 - 1. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-05-25 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 5
# Added: 2024-05-25 - 3. Come Back To Me - RM | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-06-01...
# Found 25 song rows for 2024-06-01
# Added: 2024-06-01 - 1. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 1 | Peak: 1 | Weeks: 2
# Added: 2024-06-01 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 6
# Added: 2024-06-01 - 3. Beautiful Things - Benson Boone | LW: 11 | Peak: 1 | Weeks: 18
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-06-08...
# Found 25 song rows for 2024-06-08
# Added: 2024-06-08 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 7
# Added: 2024-06-08 - 2. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 1 | Peak: 1 | Weeks: 3
# Added: 2024-06-08 - 3. Pink Skies - Zach Bryan | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-06-15...
# Found 25 song rows for 2024-06-15
# Added: 2024-06-15 - 1. Houdini - Eminem | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-06-15 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 8
# Added: 2024-06-15 - 3. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 2 | Peak: 1 | Weeks: 4
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-06-22...
# Found 25 song rows for 2024-06-22
# Added: 2024-06-22 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 9
# Added: 2024-06-22 - 2. Houdini - Eminem | LW: 1 | Peak: 1 | Weeks: 2
# Added: 2024-06-22 - 3. Never Let Go - Jung Kook | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-06-29...
# Found 25 song rows for 2024-06-29
# Added: 2024-06-29 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 10
# Added: 2024-06-29 - 2. I Am Not Okay - Jelly Roll | LW: 5 | Peak: 2 | Weeks: 2
# Added: 2024-06-29 - 3. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 4 | Peak: 1 | Weeks: 6
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-07-06...
# Found 25 song rows for 2024-07-06
# Added: 2024-07-06 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 11
# Added: 2024-07-06 - 2. Pour Me A Drink - Post Malone Featuring Blake Shelton | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-07-06 - 3. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 3 | Peak: 1 | Weeks: 7
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-07-13...
# Found 25 song rows for 2024-07-13
# Added: 2024-07-13 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 12
# Added: 2024-07-13 - 2. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 3 | Peak: 1 | Weeks: 8
# Added: 2024-07-13 - 3. Smeraldo Garden Marching Band - Jimin & Loco | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-07-20...
# Found 25 song rows for 2024-07-20
# Added: 2024-07-20 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 13
# Added: 2024-07-20 - 2. Lies Lies Lies - Morgan Wallen | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-07-20 - 3. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 2 | Peak: 1 | Weeks: 9
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-07-27...
# Found 25 song rows for 2024-07-27
# Added: 2024-07-27 - 1. You Missed - Tom MacDonald | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-07-27 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 14
# Added: 2024-07-27 - 3. Revelation - John Rich Featuring Sonya Isaacs | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-08-03...
# Found 25 song rows for 2024-08-03
# Added: 2024-08-03 - 1. Who - Jimin | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-08-03 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 15
# Added: 2024-08-03 - 3. Chk Chk Boom - Stray Kids | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-08-10...
# Found 25 song rows for 2024-08-10
# Added: 2024-08-10 - 1. Who - Jimin | LW: 1 | Peak: 1 | Weeks: 2
# Added: 2024-08-10 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 16
# Added: 2024-08-10 - 3. Lonely Road - mgk & Jelly Roll | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-08-17...
# Found 25 song rows for 2024-08-17
# Added: 2024-08-17 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 17
# Added: 2024-08-17 - 2. Leave A Light On (Talk Away The Dark) - Papa Roach & Carrie Underwood | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-08-17 - 3. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 5 | Peak: 1 | Weeks: 13
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-08-24...
# Found 25 song rows for 2024-08-24
# Added: 2024-08-24 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 18
# Added: 2024-08-24 - 2. Birds Of A Feather - Billie Eilish | LW: 14 | Peak: 2 | Weeks: 12
# Added: 2024-08-24 - 3. I Had Some Help - Post Malone Featuring Morgan Wallen | LW: 3 | Peak: 1 | Weeks: 14
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-08-31...
# Found 25 song rows for 2024-08-31
# Added: 2024-08-31 - 1. Die With A Smile - Lady Gaga & Bruno Mars | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-08-31 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 19
# Added: 2024-08-31 - 3. Ain't No Love In Oklahoma - Luke Combs | LW: 5 | Peak: 3 | Weeks: 14
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-09-07...
# Found 25 song rows for 2024-09-07
# Added: 2024-09-07 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 20
# Added: 2024-09-07 - 2. Lose Control - Teddy Swims | LW: 8 | Peak: 1 | Weeks: 59
# Added: 2024-09-07 - 3. Die With A Smile - Lady Gaga & Bruno Mars | LW: 1 | Peak: 1 | Weeks: 2
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-09-14...
# Found 25 song rows for 2024-09-14
# Added: 2024-09-14 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 21
# Added: 2024-09-14 - 2. Ain't No Love In Oklahoma - Luke Combs | LW: 4 | Peak: 2 | Weeks: 16
# Added: 2024-09-14 - 3. A Lot More Free - Max McNown | LW: 16 | Peak: 3 | Weeks: 2
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-09-21...
# Found 25 song rows for 2024-09-21
# Added: 2024-09-21 - 1. Neva Play - Megan Thee Stallion & RM | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-09-21 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 22
# Added: 2024-09-21 - 3. The Emptiness Machine - Linkin Park | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-09-28...
# Found 25 song rows for 2024-09-28
# Added: 2024-09-28 - 1. Dancing In The Flames - The Weeknd | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-09-28 - 2. Bad Dreams - Teddy Swims | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-09-28 - 3. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 23
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-10-05...
# Found 25 song rows for 2024-10-05
# Added: 2024-10-05 - 1. Fighter - Jon Kahn | LW: 4 | Peak: 1 | Weeks: 2
# Added: 2024-10-05 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 3 | Peak: 1 | Weeks: 24
# Added: 2024-10-05 - 3. I Am Not Okay - Jelly Roll | LW: 7 | Peak: 2 | Weeks: 16
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-10-12...
# Found 25 song rows for 2024-10-12
# Added: 2024-10-12 - 1. I'm Gonna Love You - Cody Johnson & Carrie Underwood | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-10-12 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 25
# Added: 2024-10-12 - 3. A Lot More Free - Max McNown | LW: 4 | Peak: 3 | Weeks: 6
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-10-19...
# Found 25 song rows for 2024-10-19
# Added: 2024-10-19 - 1. Darkest Hour (Helene Edit) - Eric Church | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-10-19 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 26
# Added: 2024-10-19 - 3. I Am Not Okay - Jelly Roll | LW: 5 | Peak: 2 | Weeks: 18
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-10-26...
# Found 25 song rows for 2024-10-26
# Added: 2024-10-26 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 27
# Added: 2024-10-26 - 2. Beautiful Things - Benson Boone | LW: 4 | Peak: 1 | Weeks: 39
# Added: 2024-10-26 - 3. Super Tuna - JIN | LW: - | Peak: 3 | Weeks: 2
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-11-02...
# Found 25 song rows for 2024-11-02
# Added: 2024-11-02 - 1. Love Somebody - Morgan Wallen | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-11-02 - 2. APT. - ROSE & Bruno Mars | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-11-02 - 3. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 28
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-11-09...
# Found 25 song rows for 2024-11-09
# Added: 2024-11-09 - 1. Die With A Smile - Lady Gaga & Bruno Mars | LW: 8 | Peak: 1 | Weeks: 11
# Added: 2024-11-09 - 2. Disease - Lady Gaga | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-11-09 - 3. I'll Be There - JIN | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-11-16...
# Found 25 song rows for 2024-11-16
# Added: 2024-11-16 - 1. Goodbye Joe - Tom MacDonald & Nova Rockafeller | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-11-16 - 2. God Bless The U.S.A. - Lee Greenwood & Drew Jacobs | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-11-16 - 3. A Bar Song (Tipsy) - Shaboozey | LW: 7 | Peak: 1 | Weeks: 30
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-11-23...
# Found 25 song rows for 2024-11-23
# Added: 2024-11-23 - 1. Hard Fought Hallelujah - Brandon Lake | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-11-23 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 3 | Peak: 1 | Weeks: 31
# Added: 2024-11-23 - 3. Die With A Smile - Lady Gaga & Bruno Mars | LW: 4 | Peak: 1 | Weeks: 13
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-11-30...
# Found 25 song rows for 2024-11-30
# Added: 2024-11-30 - 1. Running Wild - JIN | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-11-30 - 2. AGATS2 (Insecure) - Juice WRLD & Nicki Minaj | LW: - | Peak: 2 | Weeks: 1
# Added: 2024-11-30 - 3. Somethin' 'Bout A Woman - Thomas Rhett Featuring Teddy Swims | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-12-07...
# Found 25 song rows for 2024-12-07
# Added: 2024-12-07 - 1. A Bar Song (Tipsy) - Shaboozey | LW: 4 | Peak: 1 | Weeks: 33
# Added: 2024-12-07 - 2. APT. - ROSE & Bruno Mars | LW: 12 | Peak: 2 | Weeks: 6
# Added: 2024-12-07 - 3. Defying Gravity - Cynthia Erivo Featuring Ariana Grande | LW: - | Peak: 3 | Weeks: 1
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-12-14...
# Found 25 song rows for 2024-12-14
# Added: 2024-12-14 - 1. Winter Ahead - V With Park Hyo Shin | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-12-14 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 1 | Peak: 1 | Weeks: 34
# Added: 2024-12-14 - 3. APT. - ROSE & Bruno Mars | LW: 2 | Peak: 2 | Weeks: 7
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-12-21...
# Found 25 song rows for 2024-12-21
# Added: 2024-12-21 - 1. White Christmas - V & Bing Crosby | LW: - | Peak: 1 | Weeks: 1
# Added: 2024-12-21 - 2. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 35
# Added: 2024-12-21 - 3. APT. - ROSE & Bruno Mars | LW: 3 | Peak: 2 | Weeks: 8
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2024-12-28...
# Found 25 song rows for 2024-12-28
# Added: 2024-12-28 - 1. All I Want For Christmas Is You - Mariah Carey | LW: 4 | Peak: 1 | Weeks: 111
# Added: 2024-12-28 - 2. Last Christmas - Wham! | LW: 14 | Peak: 2 | Weeks: 32
# Added: 2024-12-28 - 3. A Bar Song (Tipsy) - Shaboozey | LW: 2 | Peak: 1 | Weeks: 36
# ... (collecting remaining 22 songs) ...
#
# Scraping data for 2025-01-04...
# Found 25 song rows for 2025-01-04
# Added: 2025-01-04 - 1. All I Want For Christmas Is You - Mariah Carey | LW: 1 | Peak: 1 | Weeks: 112
# Added: 2025-01-04 - 2. Last Christmas - Wham! | LW: 2 | Peak: 2 | Weeks: 33
# Added: 2025-01-04 - 3. A Bar Song (Tipsy) - Shaboozey | LW: 3 | Peak: 1 | Weeks: 37
# ... (collecting remaining 22 songs) ...
#
# All data saved to 'billboard_digital_song_sales_2024-01-06_to_2025-01-04.csv'
